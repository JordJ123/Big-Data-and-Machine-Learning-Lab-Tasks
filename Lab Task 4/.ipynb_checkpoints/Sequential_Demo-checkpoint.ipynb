# %% [markdown]
# # Lab 4 - SVMs, NN, CNN
# # Tensorflow Neural Network example on Fisher Iris Dataset

# %%
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load in the Iris data and divide it into training and testing sets

# %%
iris_data = np.load('Iris_data.npy')
iris_labels = np.load('Iris_labels.npy')

X_trn, X_tst, y_trn, y_tst = train_test_split(iris_data, iris_labels, test_size=0.2)

# %% [markdown]
# ##### Print out some stats about the data

# %%
print(f'Number of features: {X_trn.shape[1]}')
print(f'Number of training samples: {X_trn.shape[0]}')
print(f'Number of testing samples: {X_tst.shape[0]}')
print(f'Number of classes: {len(np.unique(y_trn))}')
print(f'Minimums of the features are: {X_trn.min(0)}')
print(f'Maximums of the features are: {X_trn.max(0)}')
# Out:
# Number of features: 4
# Number of training samples: 120
# Number of testing samples: 30
# Number of classes: 3
# Minimums of the features are: [4.4 2.  1.  0.1]
# Maximums of the features are: [7.9 4.4 6.7 2.5]

# %% [markdown]
# ##### Plot the first two feautre dimensions against eachother, colouring by class label

# %%
plt.figure()
plt.scatter(X_trn[:,0], X_trn[:,1], c=y_trn)
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')
plt.title('Original Data')
# Out:
# Text(0.5, 1.0, 'Original Data')

# %% [markdown]
# ## Data Standardisation

# %% [markdown]
# #### The loaded data is not standardised, as can be seen by the range covered in each feature dimension.
# Often it can be useful to standardise our feature dimensions to give them a mean of zero and a scaled variance. Many algorithms, or components of an model, presume a zero-centred and scaled variance domain. applying this standardisation can often be critical to efficient learning.
#
# #### We can use StandardScaler from the sklearn package to standardise our data based on the observed training samples.
# First, we will create a `StandardScaler` object. We then `fit` it to our training data, and then `transform` both our training and testing data using this fit model.

# %%
## Normalise the data (helps with convergence)
normaliser = StandardScaler()
X_trn = normaliser.fit_transform(X_trn)
X_tst = normaliser.transform(X_tst)

# %%
print(f'Minimums of the features are: {X_trn.min(0)}')
print(f'Maximums of the features are: {X_trn.max(0)}')

plt.figure()
plt.scatter(X_trn[:,0], X_trn[:,1], c=y_trn)
plt.xlabel('Feature Dimension 0')
plt.ylabel('Feature Dimension 1')
plt.title('Standardised Data')
# Out:
# Minimums of the features are: [-1.73573628 -2.53102292 -1.4912476  -1.37114245]
# Maximums of the features are: [2.72303581 3.06325644 1.77279515 1.75297959]
# Text(0.5, 1.0, 'Standardised Data')

# %% [markdown]
# ## Building a Tensorflow Keras model

# %% [markdown]
# ##### Now we want to create a Fully-Connected Neural Network
# In this section we will create an instance of a `tensorflow.keras.Sequential` model. Sequential allows us to pass in a list of the layers we would like to apply, in the order we wish to apply them. This is an easy way to build very simple networks, where one layer is sequentially called on the outputs of the previous layer.
#
# Here we create an instance of the `Sequential` class, passing the constructor a list of the layers we wish to use. These layers are all implemented within `tensorflow.keras.layers`. For this example, we only use `Dense` layers, which is a fully connected layer. As we can see, each layer in the list is actually a constructor call, creating their own instance of a `Dense` object/layer in our model. This example creates a neural network with 2 hidden layers (with sizes 4 and 10 respectively), and an output layer of size `len(np.unique(y_trn))` (our number of classes in the dataset).
#
# In this example, the `Dense` layers takes as input to its constructor call: the number of units/neurons, and the activation function we wish to apply to the layer's output before it is fed to the next layer in the list.

# %%
model = tf.keras.Sequential(layers=[
    tf.keras.layers.Dense(4, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.relu),
    tf.keras.layers.Dense(len(np.unique(y_trn)), activation=tf.nn.softmax)])

# %% [markdown]
# #### Now we need to compile our model, providing it with an optimiser, loss and metrics to train with
# We call the `compile()` method of our Sequential model object, passing in values for the arguments `optimizer`, `loss`, and `metrics`.
#
# * `optimizer` is an instance of a `tensorflow.keras.optimizers` class, and describes the optimization strategy used during the training of the model. In this example we use Stochastic Gradient Descent.
# * `loss` is an instance of a `tensorflow.keras.losses` class, and describes the loss to be used by the optimiser when training. In this example we use Sparse Categorical Cross-entropy, as our targets are class labels (i.e. not one-hot encoded)
# * `metric` is an instance of a `tensorflow.keras.metrics` class, and describes the accuracy metric we wish to calculate between our predictions and the ground truth. In this example we use Sparse Catergorical Accuracy as we want our accuracy to reflect the proportion of samples labelled correctly.

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
              metrics=tf.keras.metrics.SparseCategoricalAccuracy())

# %% [markdown]
# #### Now we can train out model, by calling the `fit()` function.
# We pass in our data (`X_trn`), target labels (`y_trn`), and a integer representing how many epochs we want to train our model to.
#
# We also pass a float value, `validation_split`, between 0.0 and 1.0 to further divide our training data into a training and validation set. The validation set is then used by the `fit()` method to evaluate how the model is progressing during training. This will help is see whether over- or under-fitting is occuring.
#
# We also set `verbose` to 1, so that we see the training progress printed to the console.
#
# The final thing we do is save the returned `tensorflow.keras.callbacks.History` object into the variable called history. This will let us view and plot the training curves later.

# %%
history = model.fit(X_trn, y_trn, epochs=100, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.1615 - sparse_categorical_accuracy: 0.0521 - val_loss: 1.1136 - val_sparse_categorical_accuracy: 0.0833
# Epoch 2/100
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1360 - sparse_categorical_accuracy: 0.0521 - val_loss: 1.0875 - val_sparse_categorical_accuracy: 0.0833
# Epoch 3/100
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1125 - sparse_categorical_accuracy: 0.0833 - val_loss: 1.0631 - val_sparse_categorical_accuracy: 0.1250
# Epoch 4/100
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0902 - sparse_categorical_accuracy: 0.1250 - val_loss: 1.0404 - val_sparse_categorical_accuracy: 0.1667
# Epoch 5/100
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0695 - sparse_categorical_accuracy: 0.1979 - val_loss: 1.0190 - val_sparse_categorical_accuracy: 0.2500
# Epoch 6/100
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0500 - sparse_categorical_accuracy: 0.3229 - val_loss: 0.9989 - val_sparse_categorical_accuracy: 0.4583
# Epoch 7/100
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0316 - sparse_categorical_accuracy: 0.4583 - val_loss: 0.9799 - val_sparse_categorical_accuracy: 0.5000
# Epoch 8/100
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0146 - sparse_categorical_accuracy: 0.5208 - val_loss: 0.9619 - val_sparse_categorical_accuracy: 0.5000
# Epoch 9/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9981 - sparse_categorical_accuracy: 0.5312 - val_loss: 0.9449 - val_sparse_categorical_accuracy: 0.5000
# Epoch 10/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9825 - sparse_categorical_accuracy: 0.5312 - val_loss: 0.9287 - val_sparse_categorical_accuracy: 0.5000
# Epoch 11/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9679 - sparse_categorical_accuracy: 0.5417 - val_loss: 0.9134 - val_sparse_categorical_accuracy: 0.5417
# Epoch 12/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9543 - sparse_categorical_accuracy: 0.5625 - val_loss: 0.8988 - val_sparse_categorical_accuracy: 0.5417
# Epoch 13/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9410 - sparse_categorical_accuracy: 0.5938 - val_loss: 0.8849 - val_sparse_categorical_accuracy: 0.5833
# Epoch 14/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9285 - sparse_categorical_accuracy: 0.6250 - val_loss: 0.8718 - val_sparse_categorical_accuracy: 0.6250
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9166 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.8593 - val_sparse_categorical_accuracy: 0.6667
# Epoch 16/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9051 - sparse_categorical_accuracy: 0.7292 - val_loss: 0.8473 - val_sparse_categorical_accuracy: 0.7500
# Epoch 17/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8943 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.8359 - val_sparse_categorical_accuracy: 0.8333
# Epoch 18/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8841 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.8250 - val_sparse_categorical_accuracy: 0.7917
# Epoch 19/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8740 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.8146 - val_sparse_categorical_accuracy: 0.7917
# Epoch 20/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8646 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.8047 - val_sparse_categorical_accuracy: 0.7917
# Epoch 21/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8558 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.7952 - val_sparse_categorical_accuracy: 0.7917
# Epoch 22/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8473 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.7862 - val_sparse_categorical_accuracy: 0.7917
# Epoch 23/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8388 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.7776 - val_sparse_categorical_accuracy: 0.7917
# Epoch 24/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8309 - sparse_categorical_accuracy: 0.7292 - val_loss: 0.7693 - val_sparse_categorical_accuracy: 0.7917
# Epoch 25/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8233 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7614 - val_sparse_categorical_accuracy: 0.7917
# Epoch 26/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8160 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7538 - val_sparse_categorical_accuracy: 0.7500
# Epoch 27/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8090 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7465 - val_sparse_categorical_accuracy: 0.7500
# Epoch 28/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8023 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7395 - val_sparse_categorical_accuracy: 0.7500
# Epoch 29/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7957 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7327 - val_sparse_categorical_accuracy: 0.7500
# Epoch 30/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7895 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7262 - val_sparse_categorical_accuracy: 0.7500
# Epoch 31/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7835 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7199 - val_sparse_categorical_accuracy: 0.7500
# Epoch 32/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7775 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.7139 - val_sparse_categorical_accuracy: 0.7500
# Epoch 33/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7719 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.7080 - val_sparse_categorical_accuracy: 0.7083
# Epoch 34/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7664 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.7023 - val_sparse_categorical_accuracy: 0.7083
# Epoch 35/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7611 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6968 - val_sparse_categorical_accuracy: 0.7083
# Epoch 36/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7560 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6915 - val_sparse_categorical_accuracy: 0.7083
# Epoch 37/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7510 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6864 - val_sparse_categorical_accuracy: 0.7083
# Epoch 38/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7461 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6813 - val_sparse_categorical_accuracy: 0.7083
# Epoch 39/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7414 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6765 - val_sparse_categorical_accuracy: 0.7083
# Epoch 40/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7368 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.6717 - val_sparse_categorical_accuracy: 0.7083
# Epoch 41/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7324 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6670 - val_sparse_categorical_accuracy: 0.7083
# Epoch 42/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7278 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.6625 - val_sparse_categorical_accuracy: 0.7083
# Epoch 43/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7235 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.6581 - val_sparse_categorical_accuracy: 0.7083
# Epoch 44/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7193 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.6538 - val_sparse_categorical_accuracy: 0.7083
# Epoch 45/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7152 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.6496 - val_sparse_categorical_accuracy: 0.7083
# Epoch 46/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7112 - sparse_categorical_accuracy: 0.6771 - val_loss: 0.6455 - val_sparse_categorical_accuracy: 0.7083
# Epoch 47/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7073 - sparse_categorical_accuracy: 0.6667 - val_loss: 0.6414 - val_sparse_categorical_accuracy: 0.7083
# Epoch 48/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7035 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6374 - val_sparse_categorical_accuracy: 0.7083
# Epoch 49/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6998 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.6335 - val_sparse_categorical_accuracy: 0.7083
# Epoch 50/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6959 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6297 - val_sparse_categorical_accuracy: 0.7083
# Epoch 51/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6922 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6259 - val_sparse_categorical_accuracy: 0.7083
# Epoch 52/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6886 - sparse_categorical_accuracy: 0.6875 - val_loss: 0.6222 - val_sparse_categorical_accuracy: 0.7083
# Epoch 53/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6851 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.6185 - val_sparse_categorical_accuracy: 0.7083
# Epoch 54/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6817 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.7083
# Epoch 55/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6783 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.6114 - val_sparse_categorical_accuracy: 0.7500
# Epoch 56/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6750 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.6079 - val_sparse_categorical_accuracy: 0.7500
# Epoch 57/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6718 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.6045 - val_sparse_categorical_accuracy: 0.7500
# Epoch 58/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6686 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.6011 - val_sparse_categorical_accuracy: 0.7500
# Epoch 59/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6653 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.5977 - val_sparse_categorical_accuracy: 0.7500
# Epoch 60/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6621 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.5943 - val_sparse_categorical_accuracy: 0.7500
# Epoch 61/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6590 - sparse_categorical_accuracy: 0.7083 - val_loss: 0.5910 - val_sparse_categorical_accuracy: 0.7500
# Epoch 62/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6558 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.5876 - val_sparse_categorical_accuracy: 0.7917
# Epoch 63/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6527 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.5843 - val_sparse_categorical_accuracy: 0.7917
# Epoch 64/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6496 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.5811 - val_sparse_categorical_accuracy: 0.7917
# Epoch 65/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6466 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.5778 - val_sparse_categorical_accuracy: 0.7917
# Epoch 66/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6437 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.5747 - val_sparse_categorical_accuracy: 0.8333
# Epoch 67/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6408 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.5715 - val_sparse_categorical_accuracy: 0.8333
# Epoch 68/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6381 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.5684 - val_sparse_categorical_accuracy: 0.8333
# Epoch 69/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6354 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.5653 - val_sparse_categorical_accuracy: 0.8333
# Epoch 70/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6328 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.5623 - val_sparse_categorical_accuracy: 0.8750
# Epoch 71/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6298 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.5592 - val_sparse_categorical_accuracy: 0.8750
# Epoch 72/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6271 - sparse_categorical_accuracy: 0.7396 - val_loss: 0.5561 - val_sparse_categorical_accuracy: 0.8750
# Epoch 73/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6244 - sparse_categorical_accuracy: 0.7604 - val_loss: 0.5531 - val_sparse_categorical_accuracy: 0.8750
# Epoch 74/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6218 - sparse_categorical_accuracy: 0.7500 - val_loss: 0.5500 - val_sparse_categorical_accuracy: 0.8750
# Epoch 75/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6192 - sparse_categorical_accuracy: 0.7604 - val_loss: 0.5470 - val_sparse_categorical_accuracy: 0.8750
# Epoch 76/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6165 - sparse_categorical_accuracy: 0.7604 - val_loss: 0.5439 - val_sparse_categorical_accuracy: 0.8750
# Epoch 77/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6140 - sparse_categorical_accuracy: 0.7604 - val_loss: 0.5409 - val_sparse_categorical_accuracy: 0.8750
# Epoch 78/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6114 - sparse_categorical_accuracy: 0.7812 - val_loss: 0.5379 - val_sparse_categorical_accuracy: 0.8750
# Epoch 79/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6088 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.5349 - val_sparse_categorical_accuracy: 0.8750
# Epoch 80/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6063 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.5319 - val_sparse_categorical_accuracy: 0.8750
# Epoch 81/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6038 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.5289 - val_sparse_categorical_accuracy: 0.8750
# Epoch 82/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6013 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.5259 - val_sparse_categorical_accuracy: 0.8750
# Epoch 83/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5989 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.5229 - val_sparse_categorical_accuracy: 0.8750
# Epoch 84/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5964 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.5200 - val_sparse_categorical_accuracy: 0.8750
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5942 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.5170 - val_sparse_categorical_accuracy: 0.8750
# Epoch 86/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5917 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.5137 - val_sparse_categorical_accuracy: 0.8750
# Epoch 87/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5891 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.5100 - val_sparse_categorical_accuracy: 0.8750
# Epoch 88/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5864 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.5063 - val_sparse_categorical_accuracy: 0.8750
# Epoch 89/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5836 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.5025 - val_sparse_categorical_accuracy: 0.8750
# Epoch 90/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5811 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.4987 - val_sparse_categorical_accuracy: 0.9167
# Epoch 91/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5782 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.4949 - val_sparse_categorical_accuracy: 0.9167
# Epoch 92/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5756 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.4911 - val_sparse_categorical_accuracy: 0.9167
# Epoch 93/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5729 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.4873 - val_sparse_categorical_accuracy: 0.9167
# Epoch 94/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5703 - sparse_categorical_accuracy: 0.7917 - val_loss: 0.4836 - val_sparse_categorical_accuracy: 0.9167
# Epoch 95/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5678 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.4800 - val_sparse_categorical_accuracy: 0.9167
# Epoch 96/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5653 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.4764 - val_sparse_categorical_accuracy: 0.9167
# Epoch 97/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5630 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.4728 - val_sparse_categorical_accuracy: 0.9167
# Epoch 98/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5604 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.4693 - val_sparse_categorical_accuracy: 0.9167
# Epoch 99/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5579 - sparse_categorical_accuracy: 0.8125 - val_loss: 0.4658 - val_sparse_categorical_accuracy: 0.9167
# Epoch 100/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5555 - sparse_categorical_accuracy: 0.8021 - val_loss: 0.4623 - val_sparse_categorical_accuracy: 0.9167

# %% [markdown]
# #### We can also view a summary of the layers within our Sequential model
# To do this, we use the `summary()` method of our model. This will show us layer names, layer type, output shapes, and the number of trainable parameters, which may be useful when developing or comparing models.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 20
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                50
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 103
# Trainable params: 103
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Plotting training curves: Accuracy and Loss curves
# Here we plot two sets of training curves, the first looks at how the training and validation set accuracy behaves over the epochs trained. The second looks at the loss metric over the epochs.
#
# These plots would allow us to see where we may need to make improvements in my model. For example, if both of the accuuracy curves are still increasing, and the loss is still decreasing, then perhaps my model has not converged, and I can think about training for more epochs. If my training curves are still improving, but my validation curves have stagnated, then maybe overfitting is beginning to occur.
#
# To obtain these plots, we index into the `history.history` dictionary object, using the name of what we wish to plot as the key.

# %%
plt.figure(figsize=[10,5])
plt.subplot(121)
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy',
           'Validation Accuracy'])
plt.title('Accuracy Curves')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss',
           'Validation Loss'])
plt.title('Loss Curves')
plt.show()

# %% [markdown]
# #### We can now evaluate our model to see how it performs on the testing set we created at the start.
# We can use `evaluate()` to see how our model performs on the test set. This will take in the testing data and testing labels, and will return a variable which describes the various metrics we have defined our model to use. In this case it will return a list with the contents \[`loss`, `sparse_categorical_accuracy`\] averaged across our training samples.

# %%
results = model.evaluate(X_tst, y_tst)

print(f'Test set loss: {results[0]:0.2f}, test set accuracy: {results[1]*100:0.2f}%')
# Out:
# 1/1 [==============================] - 0s 991us/step - loss: 0.6471 - sparse_categorical_accuracy: 0.7667
# Test set loss: 0.65, test set accuracy: 76.67%

# %%
plt.figure(figsize=[10,5])
plt.subplot(121)
plt.scatter(X_tst[:,0], X_tst[:,1], c=y_tst)
plt.ylabel('Feature Dimension 1')
plt.xlabel('Feature Dimension 0')
plt.title('Ground Truth')
plt.subplot(122)
plt.title('Predicted Labels')
plt.xlabel('Feature Dimension 0')
plt.scatter(X_tst[:,0], X_tst[:,1], c=np.argmax(model.predict(X_tst), axis=1))
plt.show()
